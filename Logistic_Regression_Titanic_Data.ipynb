# %%
import numpy as np
import pandas as pd
import csv

# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression

# %%
#train_data = np.genfromtxt("C:/Users/ThisPc/Desktop/Coding Ninjas/Logistic Regression/training_titanic_x_y_train.csv", delimiter = ",")
train_data = pd.read_csv("C:/Users/ThisPc/Desktop/Coding Ninjas/Logistic Regression/training_titanic_x_y_train.csv", delimiter = ",")
train_data
# Out:
#      Pclass                                               Name     Sex    Age  \
# 0         2      Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.00
# 1         3                  Williams, Mr. Howard Hugh "Harry"    male    NaN
# 2         2     Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.00
# 3         3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.00
# 4         3                             Sutehall, Mr. Henry Jr    male  25.00
# 5         3                         Lemberopolous, Mr. Peter L    male  34.50
# 6         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00
# 7         3                                 Jonkoff, Mr. Lalio    male  23.00
# 8         2                       Williams, Mr. Charles Eugene    male    NaN
# 9         3                           Rouse, Mr. Richard Henry    male  50.00
# 10        3                    Stanley, Miss. Amy Zillah Elsie  female  23.00
# ...

# %%
train_data = train_data.drop(['Cabin'],1)

# %%
train_data
# Out:
#      Pclass                                               Name     Sex    Age  \
# 0         2      Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.00
# 1         3                  Williams, Mr. Howard Hugh "Harry"    male    NaN
# 2         2     Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.00
# 3         3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.00
# 4         3                             Sutehall, Mr. Henry Jr    male  25.00
# 5         3                         Lemberopolous, Mr. Peter L    male  34.50
# 6         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00
# 7         3                                 Jonkoff, Mr. Lalio    male  23.00
# 8         2                       Williams, Mr. Charles Eugene    male    NaN
# 9         3                           Rouse, Mr. Richard Henry    male  50.00
# 10        3                    Stanley, Miss. Amy Zillah Elsie  female  23.00
# ...

# %%
titanic_train = train_data.dropna()

# %%
titanic_train.head()
# Out:
#    Pclass                                            Name     Sex   Age  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4       3                          Sutehall, Mr. Henry Jr    male  25.0
# 5       3                      Lemberopolous, Mr. Peter L    male  34.5
#
#    SibSp  Parch           Ticket     Fare Embarked  Survived
# 0      1      0           228414  26.0000        S         1
# 2      0      0           250655  26.0000        S         0
# 3      0      4           349909  21.0750        S         0
# 4      0      0  SOTON/OQ 392076   7.0500        S         0
# 5      0      0             2683   6.4375        C         0

# %%
titanic_train.shape
# Out:
# (535, 10)

# %%
titanic_train = np.array(train_data)

# %%
X_train = titanic_train[:, 0:10]

X_train.reshape(-1,1)
X_train.shape
# Out:
# (668, 10)

# %%
Y_train = titanic_train[:, 10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-99-50db08484aa1> in <module>
# ----> 1 Y_train = titanic_train[:, 10]
#
# IndexError: index 10 is out of bounds for axis 1 with size 10

# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()
classifier.fit(X_train,Y_train)
# Out:
# C:\Users\ThisPc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-d1225c5110d3> in <module>
#       1 classifier = LogisticRegression()
# ----> 2 classifier.fit(X_train,Y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# ...

# %%
classifier.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-90-c39e0230c50e> in <module>
# ----> 1 classifier.predict(X_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     279             Predicted class label per sample.
#     280         """
# --> 281         scores = self.decision_function(X)
#     282         if len(scores.shape) == 1:
#     283             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     253         if not hasattr(self, 'coef_') or self.coef_ is None:
#     254             raise NotFittedError("This %(name)s instance is not fitted "
# --> 255                                  "yet" % {'name': type(self).__name__})
#     256
#     257         X = check_array(X, accept_sparse='csr')
#
# ...

# %%
classifier.score(X_train,Y_train) # score function is a mean accracy
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-89-7d6cc4866573> in <module>
# ----> 1 classifier.score(X_train,Y_train) # score function is a mean accracy
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     288         """
#     289         from .metrics import accuracy_score
# --> 290         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     291
#     292
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     279             Predicted class label per sample.
#     280         """
# --> 281         scores = self.decision_function(X)
#     282         if len(scores.shape) == 1:
#     283             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
# ...

# %%
classifier.predict_proba(X_train) #[[prob of 0,prob of 1]] and sum these is equal to 1
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-88-9af9dcbf4d93> in <module>
# ----> 1 classifier.predict_proba(X_train) #[[prob of 0,prob of 1]] and sum these is equal to 1
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in predict_proba(self, X)
#    1403         """
#    1404         if not hasattr(self, "coef_"):
# -> 1405             raise NotFittedError("Call fit before prediction")
#    1406
#    1407         ovr = (self.multi_class in ["ovr", "warn"] or
#
# NotFittedError: Call fit before prediction

# %%
classifier.predict(X_train) - Y_train #('0' correct classification,'1' incorrect classification) )
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-87-1ff8685969d2> in <module>
# ----> 1 classifier.predict(X_train) - Y_train #('0' correct classification,'1' incorrect classification) )
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     279             Predicted class label per sample.
#     280         """
# --> 281         scores = self.decision_function(X)
#     282         if len(scores.shape) == 1:
#     283             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     253         if not hasattr(self, 'coef_') or self.coef_ is None:
#     254             raise NotFittedError("This %(name)s instance is not fitted "
# --> 255                                  "yet" % {'name': type(self).__name__})
#     256
# ...
